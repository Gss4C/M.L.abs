# %%
import pandas as pd
import seaborn as sns

# %% [markdown]
# # Ciao, sono un notebook del cazzo

# %% [markdown]
# Vediamo se docker quando lo chiudo e lo riapro riesce a ricordarso cosa gli ho installato da CLI
